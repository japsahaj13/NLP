

# %%
# We're going to put the term-document matrix into a new gensim format, from df --> sparse matrix --> gensim corpus
sparse_counts = scipy.sparse.csr_matrix(tdm)
corpus = matutils.Sparse2Corpus(sparse_counts)

# %%
# Gensim also requires dictionary of the all terms and their respective location in the term-document matrix
cv = pickle.load(open("cv_stop.pkl", "rb"))
id2word = dict((v, k) for k, v in cv.vocabulary_.items())

# %% [markdown]
# Now that we have the corpus (term-document matrix) and id2word (dictionary of location: term), we need to specify two other parameters - the number of topics and the number of passes. Let's start the number of topics at 2, see if the results make sense, and increase the number from there.

# %%
# Now that we have the corpus (term-document matrix) and id2word (dictionary of location: term),
# we need to specify two other parameters as well - the number of topics and the number of passes
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=2, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.006*"goes" + 0.006*"shit" + 0.005*"did" + 0.005*"didnt" + 0.004*"man" + 0.004*"lot" + 0.004*"life" + 0.004*"little" + 0.004*"thing" + 0.004*"okay"'),
#  (1,
#   '0.005*"went" + 0.004*"goes" + 0.004*"thing" + 0.004*"um" + 0.004*"ive" + 0.004*"look" + 0.004*"mean" + 0.003*"come" + 0.003*"id" + 0.003*"things"')]

# %%
# LDA for num_topics = 3
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=3, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.006*"look" + 0.005*"things" + 0.005*"men" + 0.004*"young" + 0.004*"yummy" + 0.003*"woman" + 0.003*"children" + 0.003*"thing" + 0.003*"stuff" + 0.003*"mean"'),
#  (1,
#   '0.007*"goes" + 0.005*"didnt" + 0.004*"did" + 0.004*"mean" + 0.004*"lot" + 0.004*"little" + 0.004*"man" + 0.004*"okay" + 0.003*"ive" + 0.003*"come"'),
#  (2,
#   '0.006*"shit" + 0.006*"thing" + 0.005*"life" + 0.004*"went" + 0.004*"did" + 0.004*"goes" + 0.004*"little" + 0.004*"guy" + 0.004*"didnt" + 0.004*"kids"')]

# %%
# LDA for num_topics = 4
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=4, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.008*"shit" + 0.006*"man" + 0.005*"lot" + 0.005*"didnt" + 0.004*"did" + 0.004*"little" + 0.004*"life" + 0.004*"make" + 0.004*"come" + 0.004*"guy"'),
#  (1,
#   '0.015*"goes" + 0.006*"shes" + 0.005*"life" + 0.005*"did" + 0.004*"thing" + 0.004*"didnt" + 0.004*"mom" + 0.004*"doing" + 0.004*"shit" + 0.003*"guy"'),
#  (2,
#   '0.006*"goes" + 0.005*"went" + 0.005*"thing" + 0.004*"ive" + 0.004*"look" + 0.004*"little" + 0.004*"did" + 0.004*"um" + 0.004*"mean" + 0.004*"come"'),
#  (3,
#   '0.007*"joke" + 0.006*"anthony" + 0.004*"guys" + 0.004*"tell" + 0.003*"grandma" + 0.003*"thing" + 0.003*"jokes" + 0.003*"did" + 0.003*"okay" + 0.003*"school"')]

# %% [markdown]
# These topics aren't looking too great. We've tried modifying our parameters. Let's try modifying our terms list as well.

# %% [markdown]
# ## Topic Modeling - Attempt #2 (Nouns Only)

# %% [markdown]
# One popular trick is to look only at terms that are from one part of speech (only nouns, only adjectives, etc.). Check out the UPenn tag set: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html.

# %%
# Let's create a function to pull out nouns from a string of text
from nltk import word_tokenize, pos_tag

def nouns(text):
    '''Given a string of text, tokenize the text and pull out only the nouns.'''
    is_noun = lambda pos: pos[:2] == 'NN'
    tokenized = word_tokenize(text)
    all_nouns = [word for (word, pos) in pos_tag(tokenized) if is_noun(pos)] 
    return ' '.join(all_nouns)

# %%
# Read in the cleaned data, before the CountVectorizer step
data_clean = pd.read_pickle('data_clean.pkl')
data_clean
# Out:
#                                                 transcript
# ali       ali wong baby cobra   transcript  scraps from...
# anthony   anthony jeselnik thoughts and prayers   full ...
# bill      bill burr im sorry you feel that way   full t...
# bo        page not found  scraps from the loft   skip t...
# dave      dave chappelle the age of spin   transcript  ...
# dusty     dusty slay workin man   transcript  scraps fr...
# dylan     dylan moran what it is   transcript  scraps f...
# gary      gary gulman its about time   transcript  scra...
# jim       jim jefferies bare   full transcript  scraps ...
# joe       joe rogan triggered   transcript  scraps from...
# john      john mulaney the comeback kid   transcript  s...
# kevin     kevin james irregardless   transcript  scraps...
# louis     louis ck oh my god   transcript  scraps from ...
# mae       mae martin sap   transcript  scraps from the ...
# matt      matt rife matthew steven rife  transcript  sc...
# mike      mike birbiglia my girlfriends boyfriend   tra...
# pete      pete davidson turbo fonzarelli   transcript  ...
# ricky     ricky gervais humanity   transcript  scraps f...
# tom       tom segura sledgehammer   transcript  scraps ...

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# Apply the nouns function to the transcripts to filter only on nouns

data_nouns = pd.DataFrame(data_clean.transcript.apply(nouns))
data_nouns
# Out:
#                                                 transcript
# ali      ali baby cobra transcript scraps skip reviewsm...
# anthony  anthony jeselnik thoughts prayers transcript s...
# bill     bill sorry way transcript scraps skip reviewsm...
# bo       page scraps skip reviewsmovie transcriptsstanl...
# dave     chappelle age spin transcript scraps skip revi...
# dusty    slay workin man transcript scraps skip reviews...
# dylan    dylan scraps skip reviewsmovie transcriptsstan...
# gary     gulman time transcript scraps skip reviewsmovi...
# jim      jim jefferies transcript scraps skip reviewsmo...
columns]

# %%
# Create the gensim corpus
corpusn = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmn.transpose()))

# Create the vocabulary dictionary
id2wordn = dict((v, k) for k, v in cvn.vocabulary_.items())

# %%
# Let's start with 2 topics
ldan = models.LdaModel(corpus=corpusn, num_topics=2, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.008*"day" + 0.007*"cause" + 0.006*"mom" + 0.006*"shes" + 0.006*"hes" + 0.006*"thing" + 0.005*"life" + 0.005*"man" + 0.005*"theyre" + 0.005*"lot"'),
#  (1,
#   '0.009*"thing" + 0.008*"man" + 0.008*"hes" + 0.008*"life" + 0.008*"day" + 0.008*"lot" + 0.007*"cause" + 0.006*"way" + 0.006*"shit" + 0.006*"guy"')]

# %%
# Let's try topics = 3
ldan = models.LdaModel(corpus=corpusn, num_topics=3, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.010*"day" + 0.009*"thing" + 0.009*"lot" + 0.008*"shit" + 0.008*"man" + 0.008*"life" + 0.007*"hes" + 0.007*"guy" + 0.007*"cause" + 0.006*"way"'),
#  (1,
#   '0.011*"hes" + 0.008*"day" + 0.008*"man" + 0.007*"life" + 0.007*"shes" + 0.006*"theyre" + 0.006*"thing" + 0.006*"way" + 0.005*"cause" + 0.005*"kids"'),
#  (2,
#   '0.009*"cause" + 0.007*"things" + 0.006*"thing" + 0.005*"mom" + 0.005*"shes" + 0.005*"men" + 0.005*"theyre" + 0.005*"point" + 0.005*"way" + 0.005*"life"')]

# %%
# Let's try 4 topics
ldan = models.LdaModel(corpus=corpusn, num_topics=4, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.009*"day" + 0.008*"cause" + 0.007*"hes" + 0.007*"guy" + 0.007*"lot" + 0.006*"thing" + 0.006*"way" + 0.006*"shes" + 0.006*"life" + 0.005*"man"'),
#  (1,
#   '0.011*"thing" + 0.010*"life" + 0.009*"things" + 0.007*"hes" + 0.007*"cause" + 0.006*"woman" + 0.006*"man" + 0.006*"day" + 0.006*"theyre" + 0.006*"men"'),
#  (2,
#   '0.010*"day" + 0.009*"lot" + 0.008*"joke" + 0.007*"shit" + 0.006*"women" + 0.006*"baby" + 0.005*"thing" + 0.005*"school" + 0.005*"husband" + 0.005*"cause"'),
#  (3,
#   '0.012*"man" + 0.009*"hes" + 0.008*"shit" + 0.008*"life" + 0.008*"day" + 0.008*"thing" + 0.007*"theyre" + 0.007*"lot" + 0.006*"fuck" + 0.006*"way"')]

# %% [markdown]
# ## Topic Modeling - Attempt #3 (Nouns and Adjectives)

# %%
# Let's create a function to pull out nouns from a string of text
def nouns_adj(text):
    '''Given a string of text, tokenize the text and pull out only the nouns and adjectives.'''
    is_noun_adj = lambda pos: pos[:2] == 'NN' or pos[:2] == 'JJ'
    tokenized = word_tokenize(text)
    nouns_adj = [word for (word, pos) in pos_tag(tokenized) if is_noun_adj(pos)] 
    return ' '.join(nouns_adj)

# %%
# Apply the nouns function to the transcripts to filter only on nouns
data_nouns_adj = pd.DataFrame(data_clean.transcript.apply(nouns_adj))
data_nouns_adj
# Out:
#                                                 transcript
# ali      ali wong baby cobra transcript scraps loft ski...
# anthony  anthony jeselnik thoughts prayers full transcr...
# bill     bill im sorry way full transcript scraps loft ...
# bo       page scraps loft skip moviesmovie reviewsmovie...
# dave     chappelle age spin transcript scraps loft skip...
# dusty    dusty slay workin man transcript scraps loft s...
# dylan    dylan transcript scraps loft skip moviesmovie ...
# gary     gary gulman time transcript scraps loft skip m...
# jim      jim jefferies full transcript scraps loft skip...
# joe      joe rogan transcript scraps loft skip moviesmo...
# john     john comeback kid transcript scraps loft skip ...
# kevin    kevin james irregardless transcript scraps lof...
# louis    louis god transcript scraps loft skip moviesmo...
# mae      mae martin sap transcript scraps loft skip mov...
# matt     matt rife steven rife transcript scraps loft s...
# mike     mike birbiglia girlfriends transcript scraps l...
# pete     pete davidson turbo fonzarelli transcript scra...
# ricky    ricky gervais humanity transcript scraps loft ...
# tom      tom segura sledgehammer transcript scraps loft...

# %%
# Create a new document-term matrix using only nouns and adjectives, also remove common words with max_df
cvna = CountVectorizer(stop_words=stop_words, max_df=.8)
data_cvna = cvna.fit_transform(data_nouns_adj.transcript)
data_dtmna = pd.DataFrame(data_cvna.toarray(), columns=cvna.get_feature_names_out())
data_dtmna.index = data_nouns_adj.index
data_dtmna
# Out:
#          aaaaah  aah  abbreviation  abbreviations  abbreviators  abc  abcs  \
# ali           0    0             0              0             0    1     0
# anthony       0    0             0              0             0    0     0
# bill          1    0             0              0             0    0     1
# bo            0    0             0              0             0    0     0
# dave          0    0             0              0             0    0     0
# dusty         0    0             0              0             0    0     0
# dylan         0    0             0              0             0    0     0
# gary          0    0             3              1             1    0     0
# jim           0    0             0              0             0    0     0
# joe           0    0             0              0             0    0     0
# john          0    0             0              0             0    0     0
# kevin         0    0             0              0             0    0     0
# louis         0    3             0              0             0    0     0
')]

# %%
# Let's try 4 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna, passes=10)
ldana.print_topics()
# Out:
# [(0,
#   '0.008*"um" + 0.004*"coffee" + 0.004*"okay" + 0.004*"uh" + 0.004*"dad" + 0.003*"fuck" + 0.003*"women" + 0.003*"kind" + 0.003*"phone" + 0.003*"talk"'),
#  (1,
#   '0.010*"shit" + 0.007*"men" + 0.007*"young" + 0.007*"women" + 0.006*"fuck" + 0.005*"ahah" + 0.004*"children" + 0.004*"fucking" + 0.004*"yummy" + 0.003*"course"'),
#  (2,
#   '0.009*"shit" + 0.008*"fuck" + 0.007*"mom" + 0.006*"okay" + 0.005*"joke" + 0.005*"kid" + 0.005*"fucking" + 0.005*"dude" + 0.004*"dad" + 0.004*"friend"'),
#  (3,
#   '0.007*"shit" + 0.006*"fck" + 0.005*"kind" + 0.004*"white" + 0.004*"women" + 0.004*"dude" + 0.003*"girl" + 0.003*"joke" + 0.003*"jenny" + 0.003*"kid"')]

# %% [markdown]
# ## Identify Topics in Each Document

# %% [markdown]
# Out of the 9 topic models we looked at, the nouns and adjectives, 4 topic one made the most sense. So let's pull that down here and run it through some more iterations to get more fine-tuned topics.

# %%
# Our final LDA model (for now)
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna, passes=80)
ldana.print_topics()
# Out:
# [(0,
#   '0.011*"shit" + 0.009*"fuck" + 0.007*"fucking" + 0.005*"women" + 0.004*"dude" + 0.004*"son" + 0.004*"uh" + 0.004*"kid" + 0.004*"ahah" + 0.003*"ass"'),
#  (1,
#   '0.007*"um" + 0.006*"kind" + 0.005*"okay" + 0.005*"shit" + 0.004*"men" + 0.004*"uh" + 0.004*"women" + 0.004*"fuck" + 0.003*"young" + 0.003*"children"'),
#  (2,
#   '0.008*"shit" + 0.008*"fck" + 0.004*"white" + 0.004*"kind" + 0.004*"women" + 0.004*"course" + 0.004*"phone" + 0.004*"fcking" + 0.004*"dude" + 0.003*"kid"'),
#  (3,
#   '0.009*"joke" + 0.007*"mom" + 0.005*"coffee" + 0.004*"okay" + 0.004*"kid" + 0.004*"fuck" + 0.004*"dad" + 0.003*"weird" + 0.003*"anthony" + 0.003*"jokes"')]

# %% [markdown]
# These four topics look pretty decent. Let's settle on these for now.
# * Topic 0: son,kid
# * Topic 1: men
# * Topic 2: phone
# * Topic 3: mom,dad

# %%
# Let's take a look at which topics each transcript contains
corpus_transformed = ldana[corpusna]
topics_and_indices = []
for doc_topics in corpus_transformed:
    topic_index, _ = max(doc_topics, key=lambda x: x[1])
    topics_and_indices.append(topic_index)

# Now, zip the topics with the document indices
result = list(zip(topics_and_indices, data_dtmna.index))

# Print the result
print(result)
# Out:
# [(1, 'ali'), (3, 'anthony'), (0, 'bill'), (3, 'bo'), (0, 'dave'), (3, 'dusty'), (1, 'dylan'), (2, 'gary'), (0, 'jim'), (2, 'joe'), (1, 'john'), (0, 'kevin'), (2, 'louis'), (1, 'mae'), (1, 'matt'), (1, 'mike'), (3, 'pete'), (3, 'ricky'), (0, 'tom')]

# %% [markdown]
# For a first pass of LDA, these kind of make sense to me, so we'll call it a day for now.
# * Topic 0: son,kid [bill,kevin,dave,jim,tom]
# * Topic 1: men [Ali, mae,dylan,matt,mike,john]
# * Topic 2: phone [gary,joe,louis]
# * Topic 3: mom,dad [anthony,dusty,pete,ricky,bo]

# %% [markdown]
# ### Assignment:
# 1. Try further modifying the parameters of the topic models above and see if you can get better topics.
# 2. Create a new topic model that includes terms from a different [part of speech](https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html) and see if you can get better topics.

# %% [markdown]
# ldana = models.LdaModel(corpus=corpusna, num_topics=5, id2word=id2wordna, passes=50)
# ldana.print_topics()

# %%
# Let's take a look at which topics each transcript contains
corpus_transformed = ldana[corpusna]
topics_and_indices = []
for doc_topics in corpus_transformed:
    topic_index, _ = max(doc_topics, key=lambda x: x[1])
    topics_and_indices.append(topic_index)

# Now, zip the topics with the document indices
result = list(zip(topics_and_indices, data_dtmna.index))

# Print the result
print(result)
# Out:
# [(2, 'ali'), (0, 'anthony'), (0, 'bill'), (1, 'bo'), (1, 'dave'), (4, 'dusty'), (1, 'dylan'), (3, 'gary'), (4, 'jim'), (1, 'joe'), (1, 'john'), (4, 'kevin'), (0, 'louis'), (0, 'mae'), (0, 'matt'), (2, 'mike'), (2, 'pete'), (0, 'ricky'), (1, 'tom')]

# %%
ldana = models.LdaModel(corpus=corpusna, num_topics=6, id2word=id2wordna, passes=50)
ldana.print_topics()
# Out:
# [(0,
#   '0.013*"um" + 0.008*"okay" + 0.006*"coffee" + 0.006*"kind" + 0.004*"fuck" + 0.004*"red" + 0.004*"dad" + 0.004*"uh" + 0.003*"talk" + 0.003*"mail"'),
#  (1,
#   '0.014*"shit" + 0.010*"fck" + 0.008*"white" + 0.008*"ahah" + 0.005*"dude" + 0.005*"fcking" + 0.005*"fuck" + 0.005*"men" + 0.005*"women" + 0.004*"kind"'),
#  (2,
#   '0.008*"women" + 0.006*"shit" + 0.006*"uh" + 0.005*"kind" + 0.005*"fucking" + 0.005*"fuck" + 0.005*"jenny" + 0.004*"ass" + 0.004*"guns" + 0.004*"sure"'),
#  (3,
#   '0.006*"men" + 0.005*"joke" + 0.005*"children" + 0.005*"fuck" + 0.004*"uh" + 0.004*"young" + 0.004*"dad" + 0.004*"women" + 0.004*"okay" + 0.004*"anthony"'),
#  (4,
#   '0.009*"joke" + 0.005*"nuts" + 0.005*"jenner" + 0.005*"chimp" + 0.005*"hampstead" + 0.004*"rape" + 0.004*"gervais" + 0.004*"funny" + 0.004*"fucking" + 0.004*"twitter"'),
#  (5,
#   '0.009*"shit" + 0.008*"mom" + 0.007*"fuck" + 0.006*"kid" + 0.005*"dude" + 0.004*"fucking" + 0.004*"kind" + 0.004*"course" + 0.003*"phone" + 0.003*"okay"')]

# %%
# Let's take a look at which topics each transcript contains
corpus_transformed = ldana[corpusna]
topics_and_indices = []
for doc_topics in corpus_transformed:
    topic_index, _ = max(doc_topics, key=lambda x: x[1])
    topics_and_indices.append(topic_index)

# Now, zip the topics with the document indices
result = list(zip(topics_and_indices, data_dtmna.index))

# Print the result
print(result)
# Out:
# [(2, 'ali'), (3, 'anthony'), (5, 'bill'), (3, 'bo'), (1, 'dave'), (0, 'dusty'), (3, 'dylan'), (5, 'gary'), (2, 'jim'), (1, 'joe'), (5, 'john'), (3, 'kevin'), (5, 'louis'), (0, 'mae'), (0, 'matt'), (2, 'mike'), (5, 'pete'), (4, 'ricky'), (3, 'tom')]

# %%
def nouns_adj_verbs(text):
    '''Given a string of text, tokenize the text and pull out only the nouns, adjectives, and verbs.'''
    is_noun_adj_verb = lambda pos: pos[:2] == 'NN' or pos[:2] == 'JJ' or pos[:2] == 'VB'
    tokenized = word_tokenize(text)
    nouns_adj_verbs = [word for (word, pos) in pos_tag(tokenized) if is_noun_adj_verb(pos)]
    return ' '.join(nouns_adj_verbs)

# %%
# Apply the new function to the transcripts to filter only on nouns, adjectives, and verbs
data_nouns_adj_verbs = pd.DataFrame(data_clean.transcript.apply(nouns_adj_verbs))

# Create a new document-term matrix using nouns, adjectives, and verbs
cvnav = CountVectorizer(stop_words=stop_words)
data_cvnav = cvnav.fit_transform(data_nouns_adj_verbs.transcript)
data_dtmnav = pd.DataFrame(data_cvnav.toarray(), columns=cvnav.get_feature_names_out())
data_dtmnav.index = data_nouns_adj_verbs.index

data_dtmnav
# Out:
#          aaaaah  aaah  aah  abandon  abbreviate  abbreviated  abbreviating  \
# ali           0     0    0        0           0            0             0
# anthony       0     0    0        0           0            0             0
# bill          1     0    0        0           0            0             0
# bo            0     0    0        0           0            0             0
# dave          0     1    0        0           0            0             0
# dusty         0     0    0        0           0            0             0
# dylan         0     0    0        0           0            0             0
# gary          0     0    0        1           1            2             3
# jim           0     0    0        0           0            0             0
# joe           0     0    0        0           0            0             0
# john          0     0    0        0           0            0             0
# kevin         0     0    0        0           0            0             0
# louis         0     0    3        0           0            0             0
# mae           0     0    0        0           0            0             0
# matt          0     0    0        0           0            0             0
# mike          0     0    0        0           0            0             0
# pete          0     0    1        0           0            0             0
# ricky         0     0    0        0           0            0             0
# tom           0     0    0        0           0            0             0
#
#          abbreviation  abbreviations  abbreviators  ...  zhlob  zillion  \
# ali                 0              0             0  ...      0        0
# anthony             0              0             0  ...      0        0
# bill                0              0             0  ...      0        1
# bo                  0              0             0  ...      0        0
# dave                0              0             0  ...      0        0
# dusty               0              0             0  ...      0        0
# dylan               0              0             0  ...      0        0
# gary                3              1             1  ...      1        0
# jim                 0              0             0  ...      0        0
# joe                 0              0             0  ...      0        0
# john                0              0             0  ...      0        0
# kevin               0              0             0  ...      0        0
# louis               0              0             0  ...      0        0
# mae                 0              0             0  ...      0        0
# matt                0              0             0  ...      0        0
# mike                0              0             0  ...      0        0
# pete                0              0             0  ...      0        0
# ricky               0              0             0  ...      0        0
# tom                 0              0             0  ...      0        0
#
#          ziploced  zombie  zombies  zone  zoning  zoo  zoom  éclair
# ali             0       1        0     0       0    0     0       0
# anthony         0       0        0     0       0    0     0       0
# bill            0       1        1     0       1    0     0       0
# bo              0       0        0     0       0    0     0       0
# dave            0       0        0     0       0    0     0       0
# dusty           0       0        0     0       0    0     0       0
# dylan           0       0        0     1       0    0     0       1
# gary            0       0        0     0       0    0     0       0
# jim             0       0        0     0       0    0     0       0
# joe             0       0        0     0       0    0     0       0
# john            0       0        0     0       0    0     0       1
# kevin           0       0        0     0       0    0     0       0
# louis           0       0        0     0       0    0     0       0
# mae             0       0        0     1       0    0     1       0
# matt            0       0        0     1       0    0     0       0
# mike            0       0        0     0       0    0     0       0
# pete            1       0        0     1       0    0     1       0
# ricky           0       0        0     0       0    1     0       0
# tom             0       0        0     0       0    1     0       0
#
# [19 rows x 10170 columns]

# %%
# Create the gensim corpus
corpusnav = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmnav.transpose()))

# Create the vocabulary dictionary
id2wordnav = dict((v, k) for k, v in cvnav.vocabulary_.items())

# %%
# Let's start with 2 topics
ldanav = models.LdaModel(corpus=corpusnav, num_topics=2, id2word=id2wordnav, passes=10)
ldanav.print_topics()
# Out:
# [(0,
#   '0.006*"gon" + 0.005*"theyre" + 0.005*"good" + 0.005*"hes" + 0.005*"man" + 0.005*"want" + 0.005*"lot" + 0.005*"going" + 0.005*"shit" + 0.005*"day"'),
#  (1,
#   '0.008*"goes" + 0.006*"fucking" + 0.006*"cause" + 0.006*"gon" + 0.006*"say" + 0.005*"going" + 0.005*"hes" + 0.005*"theyre" + 0.005*"thing" + 0.005*"did"')]

# %%
# Let's start with 3 topics
ldanav = models.LdaModel(corpus=corpusnav, num_topics=3, id2word=id2wordnav, passes=10)
ldanav.print_topics()
# Out:
# [(0,
#   '0.007*"fucking" + 0.006*"goes" + 0.006*"cause" + 0.006*"going" + 0.006*"say" + 0.005*"theyre" + 0.005*"want" + 0.005*"went" + 0.004*"theres" + 0.004*"thing"'),
#  (1,
#   '0.008*"gon" + 0.007*"shit" + 0.005*"lot" + 0.005*"good" + 0.005*"cause" + 0.005*"didnt" + 0.005*"day" + 0.005*"say" + 0.005*"theyre" + 0.004*"man"'),
#  (2,
#   '0.009*"goes" + 0.008*"hes" + 0.006*"going" + 0.006*"theyre" + 0.006*"good" + 0.005*"want" + 0.005*"um" + 0.005*"did" + 0.005*"feel" + 0.005*"gon"')]

# %%
# Let's start with 4 topics
ldanav = models.LdaModel(corpus=corpusnav, num_topics=4, id2word=id2wordnav, passes=10)
ldanav.print_topics()
# Out:
# [(0,
#   '0.009*"fucking" + 0.007*"shit" + 0.006*"gon" + 0.006*"want" + 0.006*"going" + 0.005*"hes" + 0.005*"fuck" + 0.005*"goes" + 0.005*"man" + 0.005*"theyre"'),
#  (1,
#   '0.008*"hes" + 0.007*"goes" + 0.006*"theyre" + 0.006*"good" + 0.006*"going" + 0.006*"cause" + 0.005*"gon" + 0.005*"fucking" + 0.005*"theres" + 0.005*"shes"'),
#  (2,
#   '0.005*"clinton" + 0.004*"little" + 0.004*"hey" + 0.004*"say" + 0.004*"cause" + 0.004*"mom" + 0.003*"gon" + 0.003*"day" + 0.003*"way" + 0.003*"old"'),
#  (3,
#   '0.006*"gon" + 0.006*"lot" + 0.006*"good" + 0.006*"cause" + 0.005*"say" + 0.005*"day" + 0.005*"theyre" + 0.005*"mean" + 0.004*"fcking" + 0.004*"going"')]

# %%
# Our final LDA model (for now)
ldana = models.LdaModel(corpus=corpusnav, num_topics=4, id2word=id2wordnav, passes=80)
ldana.print_topics()
# Out:
# [(0,
#   '0.009*"fucking" + 0.008*"gon" + 0.008*"shit" + 0.007*"didnt" + 0.006*"hes" + 0.005*"fuck" + 0.005*"thing" + 0.005*"say" + 0.005*"life" + 0.005*"theres"'),
#  (1,
#   '0.008*"goes" + 0.006*"hes" + 0.006*"good" + 0.005*"gon" + 0.005*"lot" + 0.005*"cause" + 0.005*"day" + 0.005*"theyre" + 0.005*"did" + 0.005*"going"'),
#  (2,
#   '0.008*"fucking" + 0.007*"going" + 0.006*"cause" + 0.006*"theyre" + 0.006*"want" + 0.005*"good" + 0.005*"man" + 0.005*"goes" + 0.005*"gon" + 0.005*"say"'),
#  (3,
#   '0.005*"say" + 0.004*"gon" + 0.004*"theyre" + 0.004*"phone" + 0.004*"saying" + 0.003*"day" + 0.003*"want" + 0.003*"trader" + 0.003*"joes" + 0.003*"dottie"')]

# %%
corpus_transformed_v = ldana[corpusnav]
topics_and_indices = []
for doc_topics in corpus_transformed_v:
    topic_index, _ = max(doc_topics, key=lambda x: x[1])
    topics_and_indices.append(topic_index)

# Now, zip the topics with the document indices
result = list(zip(topics_and_indices, data_dtmnav.index))

# Print the result
print(result)
# Out:
# [(1, 'ali'), (1, 'anthony'), (0, 'bill'), (1, 'bo'), (0, 'dave'), (1, 'dusty'), (2, 'dylan'), (3, 'gary'), (2, 'jim'), (2, 'joe'), (2, 'john'), (1, 'kevin'), (0, 'louis'), (1, 'mae'), (2, 'matt'), (1, 'mike'), (2, 'pete'), (0, 'ricky'), (1, 'tom')]
